# %%
# # output current IP -> Idea input for webscraping
# import socket # pip install socket
# hostname = socket.gethostname()
# LocalIP = socket.gethostbyname(hostname)
# import requests # pip install requests
# PuplicIP = requests.get('http://ip.42.pl/raw').text
# #print("Your Computer Name is:" + hostname + ", your local IP is " + LocalIP + "but your public IP is " + PuplicIP)
# Out:
# /de
# #
# /de
# /kaufen/immobilien/ort-altendorf/trefferliste?0-1.ILinkListener-header-login1&tab=list&o=sortToplisting-desc
# /inserieren/inserat-online-erfassen
# /mieten/immobilie-suchen
# /kaufen/immobilie-suchen
# /hypotheken
# /umziehen
# http://blog.homegate.ch/de
# #
# https://www.facebook.com/homegate.ch
# https://www.instagram.com/homegate.ch/
# https://twitter.com/homegate_Deu
# https://www.youtube.com/homegate
# https://ch.linkedin.com/company/homegate-ch-ag
# https://www.xing.com/companies/homegateag
# #
# /acheter/biens-immobiliers/lieu-altendorf/liste-annonces?tab=list&o=sortToplisting-desc
# /acquistare/immobile/luogo-altendorf/lista-annunci?tab=list&o=sortToplisting-desc
# /buy/real-estate/city-altendorf/matching-list?tab=list&o=sortToplisting-desc
# /kaufen/immobilien/ort-altendorf/trefferliste?0-1.ILinkListener-header-login2&tab=list&o=sortToplisting-desc
# /de
# http://outdatedbrowser.com/de
# https://itunes.apple.com/de/app/homegate.ch/id326131004
# ...
